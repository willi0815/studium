# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
url = "https://raw.githubusercontent.com/willi0815/studium/main/student_scores.csv"
data = pd.read_csv(url)
data.sort_values(by=['Scores'], inplace=True)
data.head()
# Out:
#     Hours  Scores
# 14    1.1      17
# 5     1.5      20
# 0     2.5      21
# 17    1.9      24
# 9     2.7      25

# %%
data1 = data['Hours'].to_numpy(dtype=np.float16)
data2 = data['Scores'].to_numpy(dtype=np.integer)
data.plot(x='Hours', y='Scores', style='o')
plt.show()

# %%
model = np.polyfit(sensorData1,sensorData2, 1)
predict = np.poly1d(model)
x_predict = range(1, 11)
y_predict = predict(x_predict)

plt.figure(figsize=(8,5))
plt.scatter(data1,data2)
plt.plot(x_predict, y_predict, c='r')
